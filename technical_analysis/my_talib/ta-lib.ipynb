# %%
import talib
import numpy

# %%
c = numpy.random.randn(100)

# %%
k, d = talib.STOCHRSI(c)

# %%
talib.SMA(c)
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan, 0.04486214,
#        0.03058254, 0.08122399, 0.15450387, 0.13019882, 0.14081026,
#        0.17367634, 0.08050411, 0.0787135 , 0.1501515 , 0.14999008,
#        0.10908706, 0.09633615, 0.11514814, 0.04914536, 0.05328182,
#        0.05474064, 0.04655827, 0.09561066, 0.17234371, 0.11101856,
#        0.10932624, 0.10226965, 0.13657266, 0.146776  , 0.16685955,
#        0.27032182, 0.25407417, 0.20821807, 0.27072071, 0.23706049,
#        0.26018593, 0.25891165, 0.23683952, 0.23469547, 0.33367564,
#        0.3267724 , 0.30452784, 0.25203824, 0.20441197, 0.26244762,
# ...

# %%
talib.RSI(c, 5)
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#        46.9314344 , 71.17783644, 50.08807351, 43.37329476, 50.17706994,
#        46.54362808, 55.59927361, 50.4733614 , 64.08291922, 44.66145203,
#        48.42014909, 48.06131923, 43.2916396 , 36.92743086, 54.90945592,
#        35.9521811 , 58.03460342, 47.8537676 , 49.91228083, 38.60478151,
#        30.49282807, 61.08752577, 56.49817892, 46.69210463, 54.63184009,
#        46.21631849, 54.58253806, 59.41310797, 45.71527366, 38.36227693,
#        55.87385721, 56.28157605, 55.15753346, 66.02892061, 48.78488694,
#        33.10920643, 54.17067531, 57.61839492, 48.92038442, 47.26970228,
#        52.24395723, 47.08036546, 64.18556967, 66.36093715, 32.49704368,
#        30.88522754, 57.50806196, 57.74827396, 51.14674663, 39.22654311,
#        54.67563578, 56.95546242, 39.46323432, 60.413118  , 42.97304849,
#        49.871587  , 52.04482086, 51.46146513, 42.13845075, 65.82877464,
# ...

# %% [markdown]
# ## Test MyTalib.py
